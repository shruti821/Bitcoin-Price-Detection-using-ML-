# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl
from scipy import stats
import statsmodels.api as sm
import warnings
from itertools import product
from datetime import datetime
warnings.filterwarnings('ignore')
plt.style.use('seaborn-poster')

# %% [markdown]
# ## Bitcoin Price. Prediction by ARIMA

# %%
data2 = pd.read_csv("C:\\Users\\1828192\\OneDrive\\Desktop\\Bitcoin\\bitstampUSD_1-min_data_2012-01-01_to_2021-03-31.csv")

# %%
data2.head()
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df = data2.copy()

# %% [markdown]
# #### Data Exploration

# %%
# Unix-time to 
df.Timestamp = pd.to_datetime(df.Timestamp, unit='s')

# Resampling to daily frequency
df.index = df.Timestamp
df = df.resample('D').mean()

# Resampling to monthly frequency
df_month = df.resample('M').mean()

# Resampling to annual frequency
df_year = df.resample('A-DEC').mean()

# Resampling to quarterly frequency
df_Q = df.resample('Q-DEC').mean()

# %%
# PLOTS
fig = plt.figure(figsize=[10, 7])
plt.suptitle('Bitcoin exchanges, mean USD', fontsize=22)

plt.subplot(221)
plt.plot(df.Weighted_Price, '-', label='By Days')
plt.legend()

plt.subplot(222)
plt.plot(df_month.Weighted_Price, '-', label='By Months')
plt.legend()

plt.subplot(223)
plt.plot(df_Q.Weighted_Price, '-', label='By Quarters')
plt.legend()

plt.subplot(224)
plt.plot(df_year.Weighted_Price, '-', label='By Years')
plt.legend()

# plt.tight_layout()
plt.show()

# %% [markdown]
# ## Stationarity check and STL-decomposition of the series

# %%
plt.figure(figsize=[10,7])
sm.tsa.seasonal_decompose(df_month.Weighted_Price).plot()
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
plt.show()
# Out:
# Dickey–Fuller test: p=0.998863

# %% [markdown]
# The series are not stationary.

# %% [markdown]
# ## Box-Cox Transformation

# %%
# Box-Cox Transformations
df_month['Weighted_Price_box'], lmbda = stats.boxcox(df_month.Weighted_Price)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.Weighted_Price)[1])
# Out:
# Dickey–Fuller test: p=0.998863

# %% [markdown]
# The series are not stationary.
#
# ## Seasonal differentiation

# %%
# Seasonal differentiation
df_month['prices_box_diff'] = df_month.Weighted_Price_box - df_month.Weighted_Price_box.shift(12)
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff[12:])[1])
# Out:
# Dickey–Fuller test: p=0.444282

# %% [markdown]
# The series are not stationary.
#
# ## Regular differentiation

# %%
# Regular differentiation
df_month['prices_box_diff2'] = df_month.prices_box_diff - df_month.prices_box_diff.shift(1)
plt.figure(figsize=(15,7))

# STL-decomposition
sm.tsa.seasonal_decompose(df_month.prices_box_diff2[13:]).plot()   
print("Dickey–Fuller test: p=%f" % sm.tsa.stattools.adfuller(df_month.prices_box_diff2[13:])[1])

plt.show()
# Out:
# Dickey–Fuller test: p=0.000024

# %% [markdown]
# The series are stationary.
#
# ## Model Selection

# %%
plt.figure(figsize=(15,7))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(df_month.prices_box_diff2[13:].values.squeeze(), lags=48, ax=ax)
ax = plt.subplot(212)
sm.graphics.tsa.plot_pacf(df_month.prices_box_diff2[13:].values.squeeze(), lags=48, ax=ax)
plt.tight_layout()
plt.show()

# %%
# Initial approximation of parameters
Qs = range(0, 2)
qs = range(0, 3)
Ps = range(0, 3)
ps = range(0, 3)
D=1
d=1
parameters = product(ps, qs, Ps, Qs)
parameters_list = list(parameters)
len(parameters_list)

# Model Selection
results = []
best_aic = float("inf")
warnings.filterwarnings('ignore')
for param in parameters_list:
    try:
        model=sm.tsa.statespace.SARIMAX(df_month.Weighted_Price_box, order=(param[0], d, param[1]), 
                                        seasonal_order=(param[2], D, param[3], 12)).fit(disp=-1)
    except ValueError:
        print('wrong parameters:', param)
        continue
    aic = model.aic
    if aic < best_aic:
        best_model = model
        best_aic = aic
        best_param = param
    results.append([param, model.aic])

# %%
# Best Models
result_table = pd.DataFrame(results)
result_table.columns = ['parameters', 'aic']
print(result_table.sort_values(by = 'aic', ascending=True).head())
print(best_model.summary())
# Out:
#       parameters         aic
# 19  (1, 0, 0, 1)  173.616767
# 21  (1, 0, 1, 1)  174.766384
# 25  (1, 1, 0, 1)  175.547247
# 37  (2, 0, 0, 1)  175.554445
# 7   (0, 1, 0, 1)  175.589833
#                                       SARIMAX Results
# ...
# Dep. Variable:                   Weighted_Price_box   No. Observations:                  112
# Model:             SARIMAX(1, 1, 0)x(0, 1, [1], 12)   Log Likelihood                 -83.808
# Date:                              Thu, 15 Apr 2021   AIC                            173.617
# Time:                                      18:56:06   BIC                            181.402
# Sample:                                  12-31-2011   HQIC                           176.767
#                                        - 03-31-2021
# Covariance Type:                                opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Analysis of residues

# %%
# STL-decomposition
plt.figure(figsize=(9,7))
plt.subplot(211)
best_model.resid[13:].plot()
plt.ylabel(u'Residuals')
ax = plt.subplot(212)
sm.graphics.tsa.plot_acf(best_model.resid[13:].values.squeeze(), lags=48, ax=ax)

print("Dickey–Fuller test:: p=%f" % sm.tsa.stattools.adfuller(best_model.resid[13:])[1])

plt.tight_layout()
plt.show()
# Out:
# Dickey–Fuller test:: p=0.000000

# %% [markdown]
# It`s OK.
#
# ## Prediction

# %%
# Inverse Box-Cox Transformation Function
def invboxcox(y,lmbda):
   if lmbda == 0:
      return(np.exp(y))
   else:
      return(np.exp(np.log(lmbda*y+1)/lmbda))

# %%
# Prediction
df_month2 = df_month[['Weighted_Price']]
date_list = [datetime(2017, 6, 30), datetime(2017, 7, 31), datetime(2017, 8, 31), datetime(2017, 9, 30), 
             datetime(2017, 10, 31), datetime(2017, 11, 30), datetime(2017, 12, 31), datetime(2018, 1, 31),
             datetime(2018, 1, 28)]
future = pd.DataFrame(index=date_list, columns= df_month.columns)
df_month2 = pd.concat([df_month2, future])
df_month2['forecast'] = invboxcox(best_model.predict(start=0, end=75), lmbda)
plt.figure(figsize=(15,7))
df_month2.Weighted_Price.plot()
df_month2.forecast.plot(color='r', ls='--', label='Predicted Weighted_Price')
plt.legend()
plt.title('Bitcoin exchanges, by months')
plt.ylabel('mean USD')
plt.show()

# %%
df1 = data2.copy()

# %%
df1.isnull().sum()
# Out:
# Timestamp                  0
# Open                 1243608
# High                 1243608
# Low                  1243608
# Close                1243608
# Volume_(BTC)         1243608
# Volume_(Currency)    1243608
# Weighted_Price       1243608
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.shape
# Out:
# (3613769, 8)

# %%
df1.isnull().sum()
# Out:
# Timestamp            0
# Open                 0
# High                 0
# Low                  0
# Close                0
# Volume_(BTC)         0
# Volume_(Currency)    0
# Weighted_Price       0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
df1.shape
# Out:
# (3613769, 8)

# %%
df1 = df1[0:10000]

# %%
df1.shape
# Out:
# (10000, 8)

# %%
X_train, X_test, y_train, y_test = train_test_split(df1.drop(['Weighted_Price'],axis=1),df1.Weighted_Price,test_size=0.2,random_state=0)

# %% [markdown]
# ## Support Vector Regression

# %%
from sklearn.svm import SVR
#Algorithm_.append('Support Vector Regression')
clf = SVR()
clf.fit(X_train, y_train)
# Out:
# SVR()

# %%
# Predicting the validation1 Set Results
predicted1 = clf.predict(X_test)

# %%
pred_final_svm =  clf.predict(X_test)

# %%
pred_final_svm
# Out:
# array([6.71861107, 6.22919901, 6.41619712, ..., 6.72061574, 6.44749974,
#        6.63848342])

# %%
from sklearn.metrics import accuracy_score
from sklearn import metrics
from sklearn.metrics import mean_squared_log_error

# %%
print('R Squared(Accuracy)', metrics.r2_score(y_test, predicted1))   
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, predicted1))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, predicted1))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, predicted1)))
# Out:
# R Squared(Accuracy) -0.05334423417031142
# Mean Absolute Error: 1.8725190857685126
# Mean Squared Error: 6.817388415165417
# Root Mean Squared Error: 2.611012909804434
